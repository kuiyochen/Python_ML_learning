# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
1+1
# Out:
# 2

# %%
print("hello world")
# Out:
# hello world

# %%
np.sin(1)
# Out:
# 0.8414709848078965

# %%
np.pi
# Out:
# 3.141592653589793

# %%
import tensorflow as tf

# %%
from tensorflow import keras as ks

# %%
plt.plot([2,34,63,2,14])

# %%
plt.plot([1,2,3,4,5],[2,34,63,2,14])

# %%
X=[1,2,3,4,5]
Y=[2,34,63,2,14]

# %%
plt.plot(X,Y)

# %%
plt.scatter(X,Y)

# %%
np.random.rand(7)
# Out:
# array([0.365585  , 0.39459725, 0.29186714, 0.47198241, 0.91723283,
#        0.20341599, 0.58970469])

# %%
np.random.randn(7)
# Out:
# array([-1.43685215,  0.30088916,  0.27357052,  0.70204086, -0.65231427,
#         0.96344696, -0.3672593 ])

# %%
plt.plot(np.random.rand(100))

# %%
x=np.linspace(0,10,1000)
y=np.sin(x)
plt.plot(x,y)
